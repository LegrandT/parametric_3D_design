# %%
import math
import matplotlib.pyplot as plt

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def generate_cos_curve(amplitude, frequency, phase, height, num_points):
    """
    Generate points for a cosine curve.

    Parameters:
    amplitude (float): The amplitude of the cosine curve.
    frequency (float): The frequency of the cosine curve.
    phase (float): The phase of the cosine curve.
    num_points (int): The number of points to generate.

    Returns:
    list: A list of tuples representing the generated points in the form (x, y).
    """

    # Generate points for cos curve
    x = list(range(num_points))
    y = [height+amplitude * np.sin(frequency * x + phase) for x in x]

    return list(zip(x, y))

def generate_sin_curve(amplitude, frequency, phase, height, num_points):
    """
    Generate points for a sine curve.

    Parameters:
    amplitude (float): The amplitude of the sine curve.
    frequency (float): The frequency of the sine curve.
    phase (float): The phase of the sine curve.
    num_points (int): The number of points to generate.

    Returns:
    list: A list of tuples representing the generated points in the form (x, y).
    """

    # Generate points for sin curve
    x = list(range(num_points))
    y = [height+amplitude * np.sin(frequency * x + phase) for x in x]

    return list(zip(x, y))

# [2 * math.sin(math.pi * i / num_layers) for i in range(num_layers)]

# Parameters
amplitude = 10 # hight of the curve
period = 10 # width of the curve
frequency = 2 * math.pi / period # frequency of the curve
phase = 0 # shift the curve to the right
num_points = 200
height = 0

# Generate points for cos curve
points_cos = generate_cos_curve(amplitude, frequency, phase, height,num_points)

# calculate the difference between one point and the next
diff = [0]+[points_cos[i+1][1] - points_cos[i][1] for i in range(len(points_cos)-1)]
print(diff)




# Plot cos curve
plt.plot([x for x, y in points_cos], [y for x, y in points_cos], label='cos')
plt.scatter([x for x, y in points_cos], [y for x, y in points_cos])
# plt.plot([x for x, y in points_cos], diff, label='diff')
plt.legend()
plt.show()
# Out:
# [0, np.float64(5.877852522924732), np.float64(3.632712640026803), np.float64(1.7763568394002505e-15), np.float64(-3.6327126400268037), np.float64(-5.877852522924732), np.float64(-5.877852522924731), np.float64(-3.6327126400268046), np.float64(-1.7763568394002505e-15), np.float64(3.632712640026803), np.float64(5.877852522924731), np.float64(5.877852522924732), np.float64(3.6327126400268055), np.float64(1.7763568394002505e-15), np.float64(-3.632712640026803), np.float64(-5.87785252292473), np.float64(-5.877852522924732), np.float64(-3.6327126400268064), np.float64(-3.552713678800501e-15), np.float64(3.6327126400268037), np.float64(5.877852522924729), np.float64(5.877852522924732), np.float64(3.632712640026808), np.float64(3.552713678800501e-15), np.float64(-3.632712640026803), np.float64(-5.877852522924729), np.float64(-5.877852522924732), np.float64(-3.632712640026809), np.float64(-3.552713678800501e-15), np.float64(3.632712640026801), np.float64(5.87785252292473), np.float64(5.877852522924732), np.float64(3.632712640026808), np.float64(5.329070518200751e-15), np.float64(-3.6327126400268), np.float64(-5.877852522924729), np.float64(-5.877852522924734), np.float64(-3.632712640026808), np.float64(-5.329070518200751e-15), np.float64(3.6327126400267993), np.float64(5.877852522924729), np.float64(5.877852522924734), np.float64(3.632712640026809), np.float64(5.329070518200751e-15), np.float64(-3.6327126400267975), np.float64(-5.87785252292473), np.float64(-5.877852522924734), np.float64(-3.63271264002681), np.float64(-7.105427357601002e-15), np.float64(3.6327126400267984), np.float64(5.877852522924729), np.float64(5.877852522924705), np.float64(3.63271264002684), np.float64(-3.552713678800501e-15), np.float64(-3.632712640026787), np.float64(-5.877852522924694), np.float64(-5.877852522924769), np.float64(-3.6327126400268215), np.float64(1.7763568394002505e-15), np.float64(3.632712640026769), np.float64(5.877852522924756), np.float64(5.877852522924763), np.float64(3.6327126400267833), np.float64(2.1316282072803006e-14), np.float64(-3.632712640026809), np.float64(-5.877852522924763), np.float64(-5.877852522924698), np.float64(-3.632712640026803), np.float64(-1.9539925233402755e-14), np.float64(3.632712640026824), np.float64(5.877852522924699), np.float64(5.877852522924705), np.float64(3.632712640026841), np.float64(0.0), np.float64(-3.6327126400267833), np.float64(-5.877852522924692), np.float64(-5.87785252292477), np.float64(-3.632712640026824), np.float64(-1.7763568394002505e-15), np.float64(3.6327126400267655), np.float64(5.877852522924757), np.float64(5.877852522924763), np.float64(3.632712640026786), np.float64(2.3092638912203256e-14), np.float64(-3.6327126400268046), np.float64(-5.877852522924763), np.float64(-5.877852522924699), np.float64(-3.6327126400268046), np.float64(-2.3092638912203256e-14), np.float64(3.6327126400268215), np.float64(5.877852522924698), np.float64(5.877852522924707), np.float64(3.6327126400268446), np.float64(3.552713678800501e-15), np.float64(-3.6327126400267824), np.float64(-5.877852522924692), np.float64(-5.877852522924771), np.float64(-3.6327126400268277), np.float64(-3.552713678800501e-15), np.float64(3.6327126400267638), np.float64(5.877852522924755), np.float64(5.877852522924766), np.float64(3.6327126400267655), np.float64(4.796163466380676e-14), np.float64(-3.632712640026803), np.float64(-5.877852522924761), np.float64(-5.8778525229247585), np.float64(-3.6327126400267487), np.float64(-2.6645352591003757e-14), np.float64(3.632712640026819), np.float64(5.877852522924627), np.float64(5.877852522924778), np.float64(3.6327126400268472), np.float64(5.329070518200751e-15), np.float64(-3.6327126400268366), np.float64(-5.877852522924632), np.float64(-5.877852522924772), np.float64(-3.6327126400268304), np.float64(-2.842170943040401e-14), np.float64(3.6327126400267833), np.float64(5.877852522924754), np.float64(5.877852522924765), np.float64(3.6327126400268135), np.float64(7.105427357601002e-15), np.float64(- ...
