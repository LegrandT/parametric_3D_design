# %%
import math
import matplotlib.pyplot as plt

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def generate_cos_curve(amplitude, frequency, phase, height, num_points):
    """
    Generate points for a cosine curve.

    Parameters:
    amplitude (float): The amplitude of the cosine curve.
    frequency (float): The frequency of the cosine curve.
    phase (float): The phase of the cosine curve.
    num_points (int): The number of points to generate.

    Returns:
    list: A list of tuples representing the generated points in the form (x, y).
    """

    # Generate points for cos curve
    x = list(range(num_points))
    y = [height+amplitude * np.sin(frequency * x + phase) for x in x]

    return list(zip(x, y))

def generate_sin_curve(amplitude, frequency, phase, height, num_points):
    """
    Generate points for a sine curve.

    Parameters:
    amplitude (float): The amplitude of the sine curve.
    frequency (float): The frequency of the sine curve.
    phase (float): The phase of the sine curve.
    num_points (int): The number of points to generate.

    Returns:
    list: A list of tuples representing the generated points in the form (x, y).
    """

    # Generate points for sin curve
    x = list(range(num_points))
    y = [height+amplitude * np.sin(frequency * x + phase) for x in x]

    return list(zip(x, y))

# [2 * math.sin(math.pi * i / num_layers) for i in range(num_layers)]

# Parameters
amplitude = 10 # hight of the curve
period = 200 # width of the curve
frequency = 2 * math.pi / period # frequency of the curve
phase = 0 # shift the curve to the right
num_points = 200
height = 0

# Generate points for cos curve
points_cos = generate_cos_curve(amplitude, frequency, phase, height,num_points)

# calculate the difference between one point and the next
diff = [0]+[points_cos[i+1][1] - points_cos[i][1] for i in range(len(points_cos)-1)]
print(diff)




# Plot cos curve
plt.plot([x for x, y in points_cos], [y for x, y in points_cos], label='cos')
plt.scatter([x for x, y in points_cos], [y for x, y in points_cos])
# plt.plot([x for x, y in points_cos], diff, label='diff')
plt.legend()
plt.show()
# Out:
# [0, np.float64(0.6279051952931337), np.float64(0.6254271403499089), np.float64(0.6204808102142036), np.float64(0.6130857257913018), np.float64(0.603271072100926), np.float64(0.5910755830973056), np.float64(0.5765473888039474), np.float64(0.559743825366426), np.float64(0.5407312087728133), np.float64(0.5195845731347655), np.float64(0.49638737456216564), np.float64(0.4712311617999898), np.float64(0.4442152149272287), np.float64(0.4154461535437761), np.float64(0.3850375159915824), np.float64(0.3531093112706767), np.float64(0.3197875454184853), np.float64(0.28520372422156015), np.float64(0.2494943342223177), np.float64(0.21280030406902029), np.float64(0.17526644833477611), np.float64(0.13704089600057578), np.float64(0.09827450585789244), np.float64(0.05912027113793705), np.float64(0.019732715717283966), np.float64(-0.019732715717283966), np.float64(-0.05912027113793883), np.float64(-0.09827450585789066), np.float64(-0.13704089600057578), np.float64(-0.17526644833477611), np.float64(-0.21280030406902029), np.float64(-0.24949433422231948), np.float64(-0.28520372422156015), np.float64(-0.3197875454184853), np.float64(-0.3531093112706749), np.float64(-0.3850375159915824), np